# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Prateek Sharma
# CS Undergrad

# %% [markdown]
# *I am very interested in Data Science because i want to contribute in developing more efficient and easy to use algorithms to meet the high demand in future.*

# %% [markdown]
# ### The code below should print ' Hello guys,I hope you're having a great day. '.

# %%
print("Hello guys,I hope you're having a great day.")
# Out:
# Hello guys,I hope you're having a great day.

# %% [markdown]
# # The secrets to a healthy life.
#    1. Eat healthy
#        - Less junk foods
#        - Healthy,balanced and nutritional diet.
#    2. Be Happy and keep learning stuff
#        - Learn new languages
#        - new skills

# %% [markdown]
# Thank You Coursera and [IBM](https://www.ibm.com).
